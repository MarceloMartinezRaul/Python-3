# %% [markdown]
# # Operadores logicos

# %% [markdown]
# Not (Negación lógica)
# Niega un valor o expresión lógica:

# %% [markdown]
# ![not.png](attachment:not.png)

# %% [markdown]
# And (Conjunción lógica)
# Devuelve verdadero sólo si se cumplen todas las condiciones:

# %% [markdown]
# ![and.png](attachment:and.png)

# %% [markdown]
# Or (Disyunción lógica)
# Devuelve verdadero si se cumple como mínimo una condición:

# %% [markdown]
# ![or.png](attachment:or.png)

# %% [markdown]
# ![tabla%20operadores%20logicos.PNG](attachment:tabla%20operadores%20logicos.PNG)
